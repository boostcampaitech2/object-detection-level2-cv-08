# %%
# 모듈 import

from mmcv import Config
from mmdet.datasets import build_dataset
from mmdet.models import build_detector
from mmdet.apis import train_detector
from mmdet.datasets import (build_dataloader, build_dataset,
                            replace_ImageToTensor)

# %%
classes = ("General trash", "Paper", "Paper pack", "Metal", "Glass", 
           "Plastic", "Styrofoam", "Plastic bag", "Battery", "Clothing")

# config file 들고오기
cfg = Config.fromfile('./configs/faster_rcnn/faster_rcnn_r50_fpn_1x_coco.py')

root='../dataset/'

# dataset config 수정
cfg.data.train.classes = classes
cfg.data.train.img_prefix = root
cfg.data.train.ann_file = root + 'train.json' # train json 정보
cfg.data.train.pipeline[2]['img_scale'] = (512,512) # Resize

cfg.data.test.classes = classes
cfg.data.test.img_prefix = root
cfg.data.test.ann_file = root + 'test.json' # test json 정보
cfg.data.test.pipeline[1]['img_scale'] = (512,512) # Resize

cfg.data.samples_per_gpu = 4

cfg.seed = 2021
cfg.gpu_ids = [0]
cfg.work_dir = './work_dirs/faster_rcnn_r50_fpn_1x_trash'

cfg.model.roi_head.bbox_head.num_classes = 10

cfg.optimizer_config.grad_clip = dict(max_norm=35, norm_type=2)
cfg.checkpoint_config = dict(max_keep_ckpts=3, interval=1)

# %%
# build_dataset
datasets = [build_dataset(cfg.data.train)]
# Out:
# loading annotations into memory...
# Done (t=0.18s)
# creating index...
# index created!

# %%
# dataset 확인
datasets[0][1]['img_metas'].data
# Out:
# {'filename': '../dataset/train/0001.jpg',
#  'ori_filename': 'train/0001.jpg',
#  'ori_shape': (1024, 1024, 3),
#  'img_shape': (512, 512, 3),
#  'pad_shape': (512, 512, 3),
#  'scale_factor': array([0.5, 0.5, 0.5, 0.5], dtype=float32),
#  'flip': False,
#  'flip_direction': None,
#  'img_norm_cfg': {'mean': array([123.675, 116.28 , 103.53 ], dtype=float32),
#   'std': array([58.395, 57.12 , 57.375], dtype=float32),
#   'to_rgb': True}}

# %%
# 모델 build 및 pretrained network 불러오기
model = build_detector(cfg.model)
model.init_weights()
# Out:
# /opt/ml/detection/mmdetection/mmdet/core/anchor/builder.py:16: UserWarning: ``build_anchor_generator`` would be deprecated soon, please use ``build_prior_generator``
#   '``build_anchor_generator`` would be deprecated soon, please use '
# 2021-09-27 15:21:15,847 - mmcv - INFO - initialize ResNet with init_cfg {'type': 'Pretrained', 'checkpoint': 'torchvision://resnet50'}
# 2021-09-27 15:21:15,847 - mmcv - INFO - load model from: torchvision://resnet50
# 2021-09-27 15:21:15,848 - mmcv - INFO - Use load_from_torchvision loader
# 2021-09-27 15:21:16,241 - mmcv - WARNING - The model and loaded state dict do not match exactly
#
# unexpected key in source state_dict: fc.weight, fc.bias
#
# 2021-09-27 15:21:16,614 - mmcv - INFO - initialize FPN with init_cfg {'type': 'Xavier', 'layer': 'Conv2d', 'distribution': 'uniform'}
# 2021-09-27 15:21:16,704 - mmcv - INFO - initialize RPNHead with init_cfg {'type': 'Normal', 'layer': 'Conv2d', 'std': 0.01}
# 2021-09-27 15:21:16,720 - mmcv - INFO - initialize Shared2FCBBoxHead with init_cfg [{'type': 'Normal', 'std': 0.01, 'override': {'name': 'fc_cls'}}, {'type': 'Normal', 'std': 0.001, 'override': {'name': 'fc_reg'}}, {'type': 'Xavier', 'layer': 'Linear', 'override': [{'name': 'shared_fcs'}, {'name': 'cls_fcs'}, {'name': 'reg_fcs'}]}]
# 2021-09-27 15:21:17,128 - mmcv - INFO -
# backbone.conv1.weight - torch.Size([64, 3, 7, 7]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,129 - mmcv - INFO -
# backbone.bn1.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,130 - mmcv - INFO -
# backbone.bn1.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,130 - mmcv - INFO -
# backbone.layer1.0.conv1.weight - torch.Size([64, 64, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,131 - mmcv - INFO -
# backbone.layer1.0.bn1.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,131 - mmcv - INFO -
# backbone.layer1.0.bn1.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,131 - mmcv - INFO -
# backbone.layer1.0.conv2.weight - torch.Size([64, 64, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,132 - mmcv - INFO -
# backbone.layer1.0.bn2.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,132 - mmcv - INFO -
# backbone.layer1.0.bn2.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,133 - mmcv - INFO -
# backbone.layer1.0.conv3.weight - torch.Size([256, 64, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,133 - mmcv - INFO -
# backbone.layer1.0.bn3.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,134 - mmcv - INFO -
# backbone.layer1.0.bn3.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,134 - mmcv - INFO -
# backbone.layer1.0.downsample.0.weight - torch.Size([256, 64, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,134 - mmcv - INFO -
# backbone.layer1.0.downsample.1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,135 - mmcv - INFO -
# backbone.layer1.0.downsample.1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,135 - mmcv - INFO -
# backbone.layer1.1.conv1.weight - torch.Size([64, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,136 - mmcv - INFO -
# backbone.layer1.1.bn1.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,136 - mmcv - INFO -
# backbone.layer1.1.bn1.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,137 - mmcv - INFO -
# backbone.layer1.1.conv2.weight - torch.Size([64, 64, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,137 - mmcv - INFO -
# backbone.layer1.1.bn2.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,138 - mmcv - INFO -
# backbone.layer1.1.bn2.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,138 - mmcv - INFO -
# backbone.layer1.1.conv3.weight - torch.Size([256, 64, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,139 - mmcv - INFO -
# backbone.layer1.1.bn3.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,139 - mmcv - INFO -
# backbone.layer1.1.bn3.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,140 - mmcv - INFO -
# backbone.layer1.2.conv1.weight - torch.Size([64, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,140 - mmcv - INFO -
# backbone.layer1.2.bn1.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,141 - mmcv - INFO -
# backbone.layer1.2.bn1.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,141 - mmcv - INFO -
# backbone.layer1.2.conv2.weight - torch.Size([64, 64, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,142 - mmcv - INFO -
# backbone.layer1.2.bn2.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,142 - mmcv - INFO -
# backbone.layer1.2.bn2.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,143 - mmcv - INFO -
# backbone.layer1.2.conv3.weight - torch.Size([256, 64, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,143 - mmcv - INFO -
# backbone.layer1.2.bn3.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,144 - mmcv - INFO -
# backbone.layer1.2.bn3.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,144 - mmcv - INFO -
# backbone.layer2.0.conv1.weight - torch.Size([128, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,145 - mmcv - INFO -
# backbone.layer2.0.bn1.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,145 - mmcv - INFO -
# backbone.layer2.0.bn1.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,146 - mmcv - INFO -
# backbone.layer2.0.conv2.weight - torch.Size([128, 128, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,146 - mmcv - INFO -
# backbone.layer2.0.bn2.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,147 - mmcv - INFO -
# backbone.layer2.0.bn2.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,147 - mmcv - INFO -
# backbone.layer2.0.conv3.weight - torch.Size([512, 128, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,148 - mmcv - INFO -
# backbone.layer2.0.bn3.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,148 - mmcv - INFO -
# backbone.layer2.0.bn3.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,149 - mmcv - INFO -
# backbone.layer2.0.downsample.0.weight - torch.Size([512, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,150 - mmcv - INFO -
# backbone.layer2.0.downsample.1.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,150 - mmcv - INFO -
# backbone.layer2.0.downsample.1.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,150 - mmcv - INFO -
# backbone.layer2.1.conv1.weight - torch.Size([128, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,151 - mmcv - INFO -
# backbone.layer2.1.bn1.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,151 - mmcv - INFO -
# backbone.layer2.1.bn1.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,152 - mmcv - INFO -
# backbone.layer2.1.conv2.weight - torch.Size([128, 128, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,152 - mmcv - INFO -
# backbone.layer2.1.bn2.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,153 - mmcv - INFO -
# backbone.layer2.1.bn2.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,153 - mmcv - INFO -
# backbone.layer2.1.conv3.weight - torch.Size([512, 128, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,154 - mmcv - INFO -
# backbone.layer2.1.bn3.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,154 - mmcv - INFO -
# backbone.layer2.1.bn3.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,155 - mmcv - INFO -
# backbone.layer2.2.conv1.weight - torch.Size([128, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,155 - mmcv - INFO -
# backbone.layer2.2.bn1.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,156 - mmcv - INFO -
# backbone.layer2.2.bn1.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,156 - mmcv - INFO -
# backbone.layer2.2.conv2.weight - torch.Size([128, 128, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,157 - mmcv - INFO -
# backbone.layer2.2.bn2.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,157 - mmcv - INFO -
# backbone.layer2.2.bn2.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,158 - mmcv - INFO -
# backbone.layer2.2.conv3.weight - torch.Size([512, 128, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,158 - mmcv - INFO -
# backbone.layer2.2.bn3.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,159 - mmcv - INFO -
# backbone.layer2.2.bn3.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,159 - mmcv - INFO -
# backbone.layer2.3.conv1.weight - torch.Size([128, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,160 - mmcv - INFO -
# backbone.layer2.3.bn1.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,160 - mmcv - INFO -
# backbone.layer2.3.bn1.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,161 - mmcv - INFO -
# backbone.layer2.3.conv2.weight - torch.Size([128, 128, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,161 - mmcv - INFO -
# backbone.layer2.3.bn2.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,162 - mmcv - INFO -
# backbone.layer2.3.bn2.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,162 - mmcv - INFO -
# backbone.layer2.3.conv3.weight - torch.Size([512, 128, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,163 - mmcv - INFO -
# backbone.layer2.3.bn3.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,163 - mmcv - INFO -
# backbone.layer2.3.bn3.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,164 - mmcv - INFO -
# backbone.layer3.0.conv1.weight - torch.Size([256, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,164 - mmcv - INFO -
# backbone.layer3.0.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,165 - mmcv - INFO -
# backbone.layer3.0.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,165 - mmcv - INFO -
# backbone.layer3.0.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,166 - mmcv - INFO -
# backbone.layer3.0.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,166 - mmcv - INFO -
# backbone.layer3.0.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,167 - mmcv - INFO -
# backbone.layer3.0.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,168 - mmcv - INFO -
# backbone.layer3.0.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,168 - mmcv - INFO -
# backbone.layer3.0.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,169 - mmcv - INFO -
# backbone.layer3.0.downsample.0.weight - torch.Size([1024, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,169 - mmcv - INFO -
# backbone.layer3.0.downsample.1.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,170 - mmcv - INFO -
# backbone.layer3.0.downsample.1.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,170 - mmcv - INFO -
# backbone.layer3.1.conv1.weight - torch.Size([256, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,171 - mmcv - INFO -
# backbone.layer3.1.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,171 - mmcv - INFO -
# backbone.layer3.1.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,171 - mmcv - INFO -
# backbone.layer3.1.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,172 - mmcv - INFO -
# backbone.layer3.1.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,172 - mmcv - INFO -
# backbone.layer3.1.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,173 - mmcv - INFO -
# backbone.layer3.1.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,173 - mmcv - INFO -
# backbone.layer3.1.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,174 - mmcv - INFO -
# backbone.layer3.1.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,174 - mmcv - INFO -
# backbone.layer3.2.conv1.weight - torch.Size([256, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,175 - mmcv - INFO -
# backbone.layer3.2.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,175 - mmcv - INFO -
# backbone.layer3.2.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,176 - mmcv - INFO -
# backbone.layer3.2.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,177 - mmcv - INFO -
# backbone.layer3.2.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,177 - mmcv - INFO -
# backbone.layer3.2.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,177 - mmcv - INFO -
# backbone.layer3.2.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,178 - mmcv - INFO -
# backbone.layer3.2.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,179 - mmcv - INFO -
# backbone.layer3.2.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,179 - mmcv - INFO -
# backbone.layer3.3.conv1.weight - torch.Size([256, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,180 - mmcv - INFO -
# backbone.layer3.3.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,180 - mmcv - INFO -
# backbone.layer3.3.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,181 - mmcv - INFO -
# backbone.layer3.3.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,181 - mmcv - INFO -
# backbone.layer3.3.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,182 - mmcv - INFO -
# backbone.layer3.3.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,182 - mmcv - INFO -
# backbone.layer3.3.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,182 - mmcv - INFO -
# backbone.layer3.3.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,183 - mmcv - INFO -
# backbone.layer3.3.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,184 - mmcv - INFO -
# backbone.layer3.4.conv1.weight - torch.Size([256, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,184 - mmcv - INFO -
# backbone.layer3.4.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,185 - mmcv - INFO -
# backbone.layer3.4.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,185 - mmcv - INFO -
# backbone.layer3.4.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,185 - mmcv - INFO -
# backbone.layer3.4.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,186 - mmcv - INFO -
# backbone.layer3.4.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,187 - mmcv - INFO -
# backbone.layer3.4.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,187 - mmcv - INFO -
# backbone.layer3.4.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,188 - mmcv - INFO -
# backbone.layer3.4.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,188 - mmcv - INFO -
# backbone.layer3.5.conv1.weight - torch.Size([256, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,189 - mmcv - INFO -
# backbone.layer3.5.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,189 - mmcv - INFO -
# backbone.layer3.5.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,189 - mmcv - INFO -
# backbone.layer3.5.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17,190 - mmcv - INFO -
# backbone.layer3.5.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-09-27 15:21:17
data_time: 0.007, memory: 1967, loss_rpn_cls: 0.1203, loss_rpn_bbox: 0.0531, loss_cls: 0.3990, acc: 91.1367, loss_bbox: 0.2754, loss: 0.8478, grad_norm: 2.3276
# 2021-09-27 15:26:38,047 - mmdet - INFO - Epoch [1][800/1221]	lr: 2.000e-02, eta: 1:31:06, time: 0.235, data_time: 0.007, memory: 1967, loss_rpn_cls: 0.0854, loss_rpn_bbox: 0.0390, loss_cls: 0.3564, acc: 91.8457, loss_bbox: 0.2477, loss: 0.7285, grad_norm: 1.9750
# 2021-09-27 15:26:49,774 - mmdet - INFO - Epoch [1][850/1221]	lr: 2.000e-02, eta: 1:28:36, time: 0.235, data_time: 0.007, memory: 1967, loss_rpn_cls: 0.0907, loss_rpn_bbox: 0.0401, loss_cls: 0.3582, acc: 91.7920, loss_bbox: 0.2461, loss: 0.7351, grad_norm: 1.7764
# 2021-09-27 15:27:01,491 - mmdet - INFO - Epoch [1][900/1221]	lr: 2.000e-02, eta: 1:26:22, time: 0.234, data_time: 0.007, memory: 1967, loss_rpn_cls: 0.0899, loss_rpn_bbox: 0.0483, loss_cls: 0.3729, acc: 90.8965, loss_bbox: 0.2758, loss: 0.7869, grad_norm: 1.8657
# 2021-09-27 15:27:13,294 - mmdet - INFO - Epoch [1][950/1221]	lr: 2.000e-02, eta: 1:24:21, time: 0.236, data_time: 0.006, memory: 1967, loss_rpn_cls: 0.1041, loss_rpn_bbox: 0.0450, loss_cls: 0.3524, acc: 91.5420, loss_bbox: 0.2499, loss: 0.7513, grad_norm: 1.8163
# 2021-09-27 15:27:25,266 - mmdet - INFO - Epoch [1][1000/1221]	lr: 2.000e-02, eta: 1:22:34, time: 0.239, data_time: 0.007, memory: 1967, loss_rpn_cls: 0.0733, loss_rpn_bbox: 0.0325, loss_cls: 0.3008, acc: 92.4727, loss_bbox: 0.2126, loss: 0.6192, grad_norm: 1.7204
# 2021-09-27 15:27:37,029 - mmdet - INFO - Epoch [1][1050/1221]	lr: 2.000e-02, eta: 1:20:53, time: 0.235, data_time: 0.007, memory: 1967, loss_rpn_cls: 0.0917, loss_rpn_bbox: 0.0440, loss_cls: 0.3589, acc: 91.1660, loss_bbox: 0.2658, loss: 0.7604, grad_norm: 1.8378
# 2021-09-27 15:27:49,223 - mmdet - INFO - Epoch [1][1100/1221]	lr: 2.000e-02, eta: 1:19:26, time: 0.244, data_time: 0.007, memory: 1967, loss_rpn_cls: 0.0919, loss_rpn_bbox: 0.0461, loss_cls: 0.3662, acc: 91.0918, loss_bbox: 0.2645, loss: 0.7688, grad_norm: 1.8207
# 2021-09-27 15:28:01,344 - mmdet - INFO - Epoch [1][1150/1221]	lr: 2.000e-02, eta: 1:18:04, time: 0.242, data_time: 0.007, memory: 1967, loss_rpn_cls: 0.0988, loss_rpn_bbox: 0.0497, loss_cls: 0.3847, acc: 90.5205, loss_bbox: 0.2837, loss: 0.8169, grad_norm: 1.9235
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_417/2854382770.py in <module>
#       1 # 모델 학습
# ----> 2 train_detector(model, datasets[0], cfg, distributed=False, validate=False)
#
# ~/detection/mmdetection/mmdet/apis/train.py in train_detector(model, dataset, cfg, distributed, validate, timestamp, meta)
#     168     elif cfg.load_from:
#     169         runner.load_checkpoint(cfg.load_from)
# --> 170     runner.run(data_loaders, cfg.workflow)
#
# /opt/conda/envs/detection/lib/python3.7/site-packages/mmcv/runner/epoch_based_runner.py in run(self, data_loaders, workflow, max_epochs, **kwargs)
#     125                     if mode == 'train' and self.epoch >= self._max_epochs:
#     126                         break
# --> 127                     epoch_runner(data_loaders[i], **kwargs)
#     128
#     129         time.sleep(1)  # wait for some hooks like loggers to finish
#
# /opt/conda/envs/detection/lib/python3.7/site-packages/mmcv/runner/epoch_based_runner.py in train(self, data_loader, **kwargs)
#      48             self._inner_iter = i
#      49             self.call_hook('before_train_iter')
# ---> 50             self.run_iter(data_batch, train_mode=True, **kwargs)
#      51             self.call_hook('after_train_iter')
#      52             self._iter += 1
#
# /opt/conda/envs/detection/lib/python3.7/site-packages/mmcv/runner/epoch_based_runner.py in run_iter(self, data_batch, train_mode, **kwargs)
#      28         elif train_mode:
#      29             outputs = self.model.train_step(data_batch, self.optimizer,
# ---> 30                                             **kwargs)
#      31         else:
#      32             outputs = self.model.val_step(data_batch, self.optimizer, **kwargs)
#
# /opt/conda/envs/detection/lib/python3.7/site-packages/mmcv/parallel/data_parallel.py in train_step(self, *inputs, **kwargs)
#      65
#      66         inputs, kwargs = self.scatter(inputs, kwargs, self.device_ids)
# ---> 67         return self.module.train_step(*inputs[0], **kwargs[0])
#      68
#      69     def val_step(self, *inputs, **kwargs):
#
# ~/detection/mmdetection/mmdet/models/detectors/base.py in train_step(self, data, optimizer)
#     235                   averaging the logs.
#     236         """
# --> 237         losses = self(**data)
#     238         loss, log_vars = self._parse_losses(losses)
#     239
#
# /opt/conda/envs/detection/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# /opt/conda/envs/detection/lib/python3.7/site-packages/mmcv/runner/fp16_utils.py in new_func(*args, **kwargs)
#      96                                 'method of nn.Module')
#      97             if not (hasattr(args[0], 'fp16_enabled') and args[0].fp16_enabled):
# ---> 98                 return old_func(*args, **kwargs)
#      99
#     100             # get the arg spec of the decorated method
#
# ~/detection/mmdetection/mmdet/models/detectors/base.py in forward(self, img, img_metas, return_loss, **kwargs)
#     169
#     170         if return_loss:
# --> 171             return self.forward_train(img, img_metas, **kwargs)
#     172         else:
#     173             return self.forward_test(img, img_metas, **kwargs)
#
# ~/detection/mmdetection/mmdet/models/detectors/two_stage.py in forward_train(self, img, img_metas, gt_bboxes, gt_labels, gt_bboxes_ignore, gt_masks, proposals, **kwargs)
#     146                                                  gt_bboxes, gt_labels,
#     147                                                  gt_bboxes_ignore, gt_masks,
# --> 148                                                  **kwargs)
#     149         losses.update(roi_losses)
#     150
#
# ~/detection/mmdetection/mmdet/models/roi_heads/standard_roi_head.py in forward_train(self, x, img_metas, proposal_list, gt_bboxes, gt_labels, gt_bboxes_ignore, gt_masks)
#     102             bbox_results = self._bbox_forward_train(x, sampling_results,
#     103                                                     gt_bboxes, gt_labels,
# --> 104                                                     img_metas)
#     105             losses.update(bbox_results['loss_bbox'])
#     106
#
# ~/detection/mmdetection/mmdet/models/roi_heads/standard_roi_head.py in _bbox_forward_train(self, x, sampling_results, gt_bboxes, gt_labels, img_metas)
#     134
#     135         bbox_targets = self.bbox_head.get_targets(sampling_results, gt_bboxes,
# --> 136                                                   gt_labels, self.train_cfg)
#     137         loss_bbox = self.bbox_head.loss(bbox_results['cls_score'],
#     138                                         bbox_results['bbox_pred'], rois,
#
# ~/detection/mmdetection/mmdet/models/roi_heads/bbox_heads/bbox_head.py in get_targets(self, sampling_results, gt_bboxes, gt_labels, rcnn_train_cfg, concat)
#     238             pos_gt_bboxes_list,
#     239             pos_gt_labels_list,
# --> 240             cfg=rcnn_train_cfg)
#     241
#     242         if concat:
#
# ~/detection/mmdetection/mmdet/core/utils/misc.py in multi_apply(func, *args, **kwargs)
#      27     pfunc = partial(func, **kwargs) if kwargs else func
#      28     map_results = map(pfunc, *args)
# ---> 29     return tuple(map(list, zip(*map_results)))
#      30
#      31
#
# ~/detection/mmdetection/mmdet/models/roi_heads/bbox_heads/bbox_head.py in _get_target_single(self, pos_bboxes, neg_bboxes, pos_gt_bboxes, pos_gt_labels, cfg)
#     166             if not self.reg_decoded_bbox:
#     167                 pos_bbox_targets = self.bbox_coder.encode(
# --> 168                     pos_bboxes, pos_gt_bboxes)
#     169             else:
#     170                 # When the regression loss (e.g. `IouLoss`, `GIouLoss`)
#
# ~/detection/mmdetection/mmdet/core/bbox/coder/delta_xywh_bbox_coder.py in encode(self, bboxes, gt_bboxes)
#      57         assert bboxes.size(0) == gt_bboxes.size(0)
#      58         assert bboxes.size(-1) == gt_bboxes.size(-1) == 4
# ---> 59         encoded_bboxes = bbox2delta(bboxes, gt_bboxes, self.means, self.stds)
#      60         return encoded_bboxes
#      61
#
# /opt/conda/envs/detection/lib/python3.7/site-packages/mmcv/utils/parrots_jit.py in wrapper_inner(*args, **kargs)
#      20
#      21             def wrapper_inner(*args, **kargs):
# ---> 22                 return func(*args, **kargs)
#      23
#      24             return wrapper_inner
#
# ~/detection/mmdetection/mmdet/core/bbox/coder/delta_xywh_bbox_coder.py in bbox2delta(proposals, gt, means, stds)
#     134     deltas = torch.stack([dx, dy, dw, dh], dim=-1)
#     135
# --> 136     means = deltas.new_tensor(means).unsqueeze(0)
#     137     stds = deltas.new_tensor(stds).unsqueeze(0)
#     138     deltas = deltas.sub_(means).div_(stds)
#
# KeyboardInterrupt:

# %%
# !nvcc -V

# %%
# !conda list | grep cuda
# Out:
# cudatoolkit               11.0.221             h6bb024c_0
# pytorch                   1.7.1           py3.7_cuda11.0.221_cudnn8.0.5_0    pytorch

# %%
# !pip install --ignore-installed mmcv-full==1.3.14 -f https://download.openmmlab.com/mmcv/dist/cu110/torch1.7.0/index.html
# Out:
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu110/torch1.7.0/index.html
# Collecting mmcv-full==1.3.14
#   Downloading https://download.openmmlab.com/mmcv/dist/cu110/torch1.7.0/mmcv_full-1.3.14-cp37-cp37m-manylinux1_x86_64.whl (33.2 MB)
#      |████████████████████████████████| 33.2 MB 13.4 MB/s eta 0:00:01
# Collecting opencv-python>=3
#   Using cached opencv_python-4.5.3.56-cp37-cp37m-manylinux2014_x86_64.whl (49.9 MB)
# Collecting Pillow
#   Downloading Pillow-8.3.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 20.9 MB/s eta 0:00:01
# Collecting pyyaml
#   Using cached PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
# Collecting packaging
#   Using cached packaging-21.0-py3-none-any.whl (40 kB)
# Collecting yapf
#   Using cached yapf-0.31.0-py2.py3-none-any.whl (185 kB)
# Collecting addict
#   Using cached addict-2.4.0-py3-none-any.whl (3.8 kB)
# Collecting numpy
#   Downloading numpy-1.21.2-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
#      |████████████████████████████████| 15.7 MB 77.8 MB/s eta 0:00:01
# Collecting pyparsing>=2.0.2
#   Using cached pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
# Installing collected packages: pyparsing, numpy, yapf, pyyaml, Pillow, packaging, opencv-python, addict, mmcv-full
# Successfully installed Pillow-8.3.2 addict-2.4.0 mmcv-full-1.3.14 numpy-1.21.2 opencv-python-4.5.3.56 packaging-21.0 pyparsing-2.4.7 pyyaml-5.4.1 yapf-0.31.0
